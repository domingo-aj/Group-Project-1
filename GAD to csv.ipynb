# %%
import pandas as pd

# %%
df = pd.read_csv('GlobalAirportDatabase/GlobalAirportDatabase.txt', sep=':', header=None, 
            names=["ICAO Code", "IATA Code", "Airport Name", "City/Town", "Country", 
                   "Latitude Degrees", "Latitude Minutes", "Latitude Seconds", 
                   "Latitude Direction", "Longitude Degrees", "Longitude Minutes", 
                   "Longitude Seconds", "Longitude Direction", "Altitude",
                   "Latitude Decimal Degrees", "Longitude Decimal Degrees"])

# %%
df
# Out:
#      ICAO Code IATA Code Airport Name    City/Town           Country  \
# 0         AYGA       GKA       GOROKA       GOROKA  PAPUA NEW GUINEA
# 1         AYLA       LAE          NaN          LAE  PAPUA NEW GUINEA
# 2         AYMD       MAG       MADANG       MADANG  PAPUA NEW GUINEA
# 3         AYMH       HGU  MOUNT HAGEN  MOUNT HAGEN  PAPUA NEW GUINEA
# 4         AYNZ       LAE       NADZAB       NADZAB  PAPUA NEW GUINEA
# ...        ...       ...          ...          ...               ...
# 9295      ZYTK       NaN          NaN     SHENYANG             CHINA
# 9296      ZYTL       DLC   ZHOUSHUIZI       DALIAN             CHINA
# 9297      ZYXC       NaN          NaN    XIANCHENG             CHINA
# 9298      ZYYC       NaN          NaN       YICHUN             CHINA
# 9299      ZYYJ       NaN        YANJI        YANJI             CHINA
#
#       Latitude Degrees  Latitude Minutes  Latitude Seconds Latitude Direction  \
# ...

# %%
gad_df = df.drop(columns=["Latitude Degrees", "Latitude Minutes", "Latitude Seconds", 
                   "Latitude Direction", "Longitude Degrees", "Longitude Minutes", 
                   "Longitude Seconds", "Longitude Direction", "Altitude"])

# %%
gad_df
# Out:
#      ICAO Code IATA Code Airport Name    City/Town           Country  \
# 0         AYGA       GKA       GOROKA       GOROKA  PAPUA NEW GUINEA
# 1         AYLA       LAE          NaN          LAE  PAPUA NEW GUINEA
# 2         AYMD       MAG       MADANG       MADANG  PAPUA NEW GUINEA
# 3         AYMH       HGU  MOUNT HAGEN  MOUNT HAGEN  PAPUA NEW GUINEA
# 4         AYNZ       LAE       NADZAB       NADZAB  PAPUA NEW GUINEA
# ...        ...       ...          ...          ...               ...
# 9295      ZYTK       NaN          NaN     SHENYANG             CHINA
# 9296      ZYTL       DLC   ZHOUSHUIZI       DALIAN             CHINA
# 9297      ZYXC       NaN          NaN    XIANCHENG             CHINA
# 9298      ZYYC       NaN          NaN       YICHUN             CHINA
# 9299      ZYYJ       NaN        YANJI        YANJI             CHINA
#
#       Latitude Decimal Degrees  Longitude Decimal Degrees
# 0                       -6.082                    145.392
# ...

# %%
gad_df.to_csv('GlobalAirportDatabase/GlobalAirportDatabaseClean.csv', index=False)

# %%
#csv back to dataframe

pd.read_csv('GlobalAirportDatabase/GlobalAirportDatabaseClean.csv')
# Out:
#      ICAO Code IATA Code Airport Name    City/Town           Country  \
# 0         AYGA       GKA       GOROKA       GOROKA  PAPUA NEW GUINEA
# 1         AYLA       LAE          NaN          LAE  PAPUA NEW GUINEA
# 2         AYMD       MAG       MADANG       MADANG  PAPUA NEW GUINEA
# 3         AYMH       HGU  MOUNT HAGEN  MOUNT HAGEN  PAPUA NEW GUINEA
# 4         AYNZ       LAE       NADZAB       NADZAB  PAPUA NEW GUINEA
# ...        ...       ...          ...          ...               ...
# 9295      ZYTK       NaN          NaN     SHENYANG             CHINA
# 9296      ZYTL       DLC   ZHOUSHUIZI       DALIAN             CHINA
# 9297      ZYXC       NaN          NaN    XIANCHENG             CHINA
# 9298      ZYYC       NaN          NaN       YICHUN             CHINA
# 9299      ZYYJ       NaN        YANJI        YANJI             CHINA
#
#       Latitude Decimal Degrees  Longitude Decimal Degrees
# 0                       -6.082                    145.392
# ...
