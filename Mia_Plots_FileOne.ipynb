# %%
import pandas as pd 
import matplotlib.pyplot as plt
import scipy.stats as st
import numpy as np
from scipy.stats import sem
import datetime

# %%
summary2015 = pd.read_csv('Data_Cleaning/clean_data/focused_airports_2015.csv', index_col=0)
summary2016 = pd.read_csv('Data_Cleaning/clean_data/focused_airports_2016.csv', index_col=0)
summary2017 = pd.read_csv('Data_Cleaning/clean_data/focused_airports_2017.csv', index_col=0)
summary2018 = pd.read_csv('Data_Cleaning/clean_data/focused_airports_2018.csv', index_col=0)

summary1 = summary2015.append(summary2016)
summary2 = summary1.append(summary2017)
summary = summary2.append(summary2018)

total_flights = summary.reset_index()

# %%
#All Flights
total_flights
# Out:
#                Date Origin Destination  Expected Departure Time  \
# 0        2015-01-01    DFW         BWI                     1342
# 1        2015-01-01    ORD         OAK                     1534
# 2        2015-01-01    LAX         IAH                     1648
# 3        2015-01-01    ORD         ATL                     1105
# 4        2015-01-01    ORD         GRB                     1310
# ...             ...    ...         ...                      ...
# 5324042  2018-12-31    LAX         IAH                      720
# 5324043  2018-12-31    ORD         PHL                     2035
# 5324044  2018-12-31    LAX         PHL                      720
# 5324045  2018-12-31    DFW         MCI                     1725
# 5324046  2018-12-31    DFW         PHL                     1955
#
#          Expected Arrival Time  Distance Weather Delay
# 0                         1724    1217.0             0
# 1                         1819    1836.0             0
# 2                         2155    1379.0             0
# 3                         1355     606.0             0
# 4                         1358     173.0             0
# ...                        ...       ...           ...
# 5324042                   1235    1379.0             0
# 5324043                   2331     678.0             0
# 5324044                   1522    2402.0             0
# 5324045                   1856     460.0             0
# 5324046                   2357    1303.0             0
#
# [5324047 rows x 7 columns]

# %%
flight_summary = pd.read_csv('Summary Flight Tables/airport_summary.csv', index_col=0)
monthly_summary = pd.read_csv('Summary Flight Tables/monthly_summary.csv', index_col=0)
weather_summary = pd.read_csv('airport_weather_data_result.csv', index_col=0)

# %%
#Cancelled and Non-Cancelled Flights by Airport
flight_summary
# Out:
#   Airport  # Cancelled Flights  # Non-Cancelled Flights  Total Flights
# 0     DFW                10181                   900961         911142
# 1     ATL                 7701                  1505703        1513404
# 2     DEN                 5989                   891080         897069
# 3     LAX                 2372                   853024         855396
# 4     ORD                13418                  1133618        1147036

# %%
#Total Cancelled and Non-Cancelled Flights
monthly_summary
# Out:
#           Date  # Cancelled Flights  # Non-Cancelled Flights  Total Flights
# 0   2015-01-31                 1250                   108150         109400
# 1   2015-02-28                 4296                    96062         100358
# 2   2015-03-31                 1759                   116298         118057
# 3   2015-04-30                  585                   112765         113350
# 4   2015-05-31                  919                   116066         116985
# 5   2015-06-30                  886                   117737         118623
# 6   2015-07-31                  243                   122228         122471
# 7   2015-08-31                  355                   121185         121540
# 8   2015-09-30                  187                   112242         112429
# 9   2015-10-31                  371                   116546         116917
# 10  2015-11-30                  836                   108694         109530
# 11  2015-12-31                 1816                   109926         111742
# 12  2016-01-31                 1138                    97493          98631
# 13  2016-02-29                  826                    92533          93359
# 14  2016-03-31                 1016                   104878         105894
# 15  2016-04-30                  816                   102052         102868
# 16  2016-05-31                  257                   107708         107965
# 17  2016-06-30                  496                   109361         109857
# 18  2016-07-31                  539                   112555         113094
# 19  2016-08-31                  516                   112276         112792
# 20  2016-09-30                   93                   104505         104598
# 21  2016-10-31                  423                   107406         107829
# 22  2016-11-30                  140                   100034         100174
# 23  2016-12-31                 1174                    99258         100432
# 24  2017-01-31                 1087                    96814          97901
# 25  2017-02-28                  483                    89559          90042
# 26  2017-03-31                  882                   105425         106307
# 27  2017-04-30                  875                    99764         100639
# 28  2017-05-31                  154                   107633         107787
# 29  2017-06-30                  581                   109650         110231
# 30  2017-07-31                  655                   112490         113145
# 31  2017-08-31                  871                   112598         113469
# 32  2017-09-30                 1764                   100344         102108
# 33  2017-10-31                  154                   105646         105800
# 34  2017-11-30                   52                    97842          97894
# 35  2017-12-31                 1033                    97429          98462
# 36  2018-01-31                 1757                   112316         114073
# 37  2018-02-28                 1331                   102340         103671
# 38  2018-03-31                 1173                   119754         120927
# 39  2018-04-30                  392                   118218         118610
# 40  2018-05-31                  728                   123433         124161
# 41  2018-06-30                  720                   126134         126854
# 42  2018-07-31                  620                   130550         131170
# 43  2018-08-31                  566                   130750         131316
# 44  2018-09-30                  842                   118708         119550
# 45  2018-10-31                  476                   124570         125046
# 46  2018-11-30                  861                   116410         117271
# 47  2018-12-31                  667                   118051         118718

# %%
#Total Weather Summary
weather_summary
# Out:
#             Date Airport  Latitude  Longitude  Max Temp  Precip Precip Type  \
# 0     2015-01-01     DFW    32.896    -97.037      36.0    0.58  rain,snow,
# 1     2015-01-02     DFW    32.896    -97.037      39.8    0.28       rain,
# 2     2015-01-03     DFW    32.896    -97.037      54.0    0.43       rain,
# 3     2015-01-04     DFW    32.896    -97.037      43.1    0.00         NaN
# 4     2015-01-05     DFW    32.896    -97.037      46.1    0.00         NaN
# ...          ...     ...       ...        ...       ...     ...         ...
# 7300  2018-12-27     ORD    41.979    -87.904      53.1    0.66       rain,
# 7301  2018-12-28     ORD    41.979    -87.904      53.1    0.06       rain,
# 7302  2018-12-29     ORD    41.979    -87.904      29.9    0.07  rain,snow,
# 7303  2018-12-30     ORD    41.979    -87.904      35.1    0.00         NaN
# 7304  2018-12-31     ORD    41.979    -87.904      38.9    0.86  rain,snow,
#
#       Wind Speed
# 0            8.0
# 1           11.4
# 2           12.7
# 3           27.7
# 4           16.1
# ...          ...
# 7300        20.8
# 7301        23.0
# 7302        17.2
# 7303        17.2
# 7304        18.3
#
# [7305 rows x 8 columns]

# %%
weather_summary['Date'] = pd.to_datetime(weather_summary['Date'])

# %%
weather_summary.dtypes
# Out:
# Date           datetime64[ns]
# Airport                object
# Latitude              float64
# Longitude             float64
# Max Temp              float64
# Precip                float64
# Precip Type            object
# Wind Speed            float64
# dtype: object

# %%
weather_summary
# Out:
#            Date Airport  Latitude  Longitude  Max Temp  Precip Precip Type  \
# 0    2015-01-01     DFW    32.896    -97.037      36.0    0.58  rain,snow,
# 1    2015-01-02     DFW    32.896    -97.037      39.8    0.28       rain,
# 2    2015-01-03     DFW    32.896    -97.037      54.0    0.43       rain,
# 3    2015-01-04     DFW    32.896    -97.037      43.1    0.00         NaN
# 4    2015-01-05     DFW    32.896    -97.037      46.1    0.00         NaN
# ...         ...     ...       ...        ...       ...     ...         ...
# 7300 2018-12-27     ORD    41.979    -87.904      53.1    0.66       rain,
# 7301 2018-12-28     ORD    41.979    -87.904      53.1    0.06       rain,
# 7302 2018-12-29     ORD    41.979    -87.904      29.9    0.07  rain,snow,
# 7303 2018-12-30     ORD    41.979    -87.904      35.1    0.00         NaN
# 7304 2018-12-31     ORD    41.979    -87.904      38.9    0.86  rain,snow,
#
#       Wind Speed
# 0            8.0
# 1           11.4
# 2           12.7
# 3           27.7
# 4           16.1
# ...          ...
# 7300        20.8
# 7301        23.0
# 7302        17.2
# 7303        17.2
# 7304        18.3
#
# [7305 rows x 8 columns]

# %%
#Temp vs lat for cancelled flights 
plt.scatter(weather_summary['Latitude'],weather_summary['Wind Speed'],c=weather_summary['Wind Speed'])
clb = plt.colorbar()
plt.xlabel("Latitude")
plt.ylabel("Wind Speed")
clb.set_label("Wind Speed")
plt.show()

# %%
#Temp vs precipitation & for cancelled flights 
plt.scatter(weather_summary['Precip'],weather_summary['Max Temp'],c=weather_summary['Wind Speed'])
clb = plt.colorbar()
plt.xlabel("Precipitation (In)")
plt.ylabel("Max Temp (F)")
clb.set_label("Wind Speed")
plt.show()

# %%
#Correlation
precip = weather_summary.iloc[:,5]
max_temp = weather_summary.iloc[:,4]
correlation = st.pearsonr(precip,max_temp)
print(f"The correlation between both factors is {round(correlation[0],2)}")
# Out:
# The correlation between both factors is -0.03

# %%
#Temp vs Wind Speed & for cancelled flights 
plt.scatter(weather_summary['Max Temp'],weather_summary['Wind Speed'],c=weather_summary['Precip'])
clb = plt.colorbar()
plt.xlabel("Wind Speed")
plt.ylabel("Max Temp (F)")
clb.set_label("Precipitation (In)")
plt.show()

# %%
#Correlation
wind_speed = weather_summary.iloc[:,7]
max_temp = weather_summary.iloc[:,4]
correlation = st.pearsonr(wind_speed,max_temp)
print(f"The correlation between both factors is {round(correlation[0],2)}")
# Out:
# The correlation between both factors is -0.07

# %%
#Wind speed vs precipitation &  temp as colored data points for cancelled flights 
plt.scatter(weather_summary['Wind Speed'],weather_summary['Precip'],c=weather_summary['Max Temp'])
clb = plt.colorbar()
plt.xlabel("Wind Speed")
plt.ylabel("Precipitation (In)")
clb.set_label("Max Temp (F)")
plt.show()

# %%
#Correlation
wind_speed = weather_summary.iloc[:,7]
precip = weather_summary.iloc[:,5]
correlation = st.pearsonr(wind_speed,precip)
print(f"The correlation between both factors is {round(correlation[0],2)}")
# Out:
# The correlation between both factors is 0.09

# %%
pe_slope, pe_int, pe_r, pe_p, pe_std_err = st.linregress(wind_speed, precip)
pe_fit = pe_slope * wind_speed + pe_int

# %%
plt.scatter(weather_summary['Wind Speed'],weather_summary['Precip'],c=weather_summary['Max Temp'])
clb = plt.colorbar()
plt.xlabel("Wind Speed")
plt.ylabel("Precip")
clb.set_label("Max Temp")
plt.plot(wind_speed,pe_fit,"--")
plt.show()

# %%
weather_summary.dtypes
# Out:
# Date           datetime64[ns]
# Airport                object
# Latitude              float64
# Longitude             float64
# Max Temp              float64
# Precip                float64
# Precip Type            object
# Wind Speed            float64
# dtype: object

# %%
weather_summary['Month Name'] = weather_summary['Date'].dt.month_name()
weather_summary
# Out:
#            Date Airport  Latitude  Longitude  Max Temp  Precip Precip Type  \
# 0    2015-01-01     DFW    32.896    -97.037      36.0    0.58  rain,snow,
# 1    2015-01-02     DFW    32.896    -97.037      39.8    0.28       rain,
# 2    2015-01-03     DFW    32.896    -97.037      54.0    0.43       rain,
# 3    2015-01-04     DFW    32.896    -97.037      43.1    0.00         NaN
# 4    2015-01-05     DFW    32.896    -97.037      46.1    0.00         NaN
# ...         ...     ...       ...        ...       ...     ...         ...
# 7300 2018-12-27     ORD    41.979    -87.904      53.1    0.66       rain,
# 7301 2018-12-28     ORD    41.979    -87.904      53.1    0.06       rain,
# 7302 2018-12-29     ORD    41.979    -87.904      29.9    0.07  rain,snow,
# 7303 2018-12-30     ORD    41.979    -87.904      35.1    0.00         NaN
# 7304 2018-12-31     ORD    41.979    -87.904      38.9    0.86  rain,snow,
#
#       Wind Speed Month Name
# 0            8.0    January
# 1           11.4    January
# 2           12.7    January
# 3           27.7    January
# 4           16.1    January
# ...          ...        ...
# 7300        20.8   December
# 7301        23.0   December
# 7302        17.2   December
# 7303        17.2   December
# 7304        18.3   December
#
# [7305 rows x 9 columns]

# %%
monthly_weather = weather_summary[['Date','Month Name', 'Airport', 'Latitude', 'Longitude', 'Max Temp', 'Precip', 'Precip Type','Wind Speed']]
monthly_weather.head()
# Out:
#         Date Month Name Airport  Latitude  Longitude  Max Temp  Precip  \
# 0 2015-01-01    January     DFW    32.896    -97.037      36.0    0.58
# 1 2015-01-02    January     DFW    32.896    -97.037      39.8    0.28
# 2 2015-01-03    January     DFW    32.896    -97.037      54.0    0.43
# 3 2015-01-04    January     DFW    32.896    -97.037      43.1    0.00
# 4 2015-01-05    January     DFW    32.896    -97.037      46.1    0.00
#
#   Precip Type  Wind Speed
# 0  rain,snow,         8.0
# 1       rain,        11.4
# 2       rain,        12.7
# 3         NaN        27.7
# 4         NaN        16.1

# %%
max_temp_average = monthly_weather.groupby('Month Name')['Max Temp'].mean()
max_temp_average.sort_values()
max_temp_average
# Out:
# Month Name
# April        67.548500
# August       85.485806
# December     52.995161
# February     54.949735
# January      50.480000
# July         87.069839
# June         83.158500
# March        62.058710
# May          74.060484
# November     61.920333
# October      72.758226
# September    82.088833
# Name: Max Temp, dtype: float64

# %%
precip_average = monthly_weather.groupby('Month Name')['Precip'].mean()
precip_average
# Out:
# Month Name
# April        0.100567
# August       0.086065
# December     0.101468
# February     0.101982
# January      0.085855
# July         0.078323
# June         0.108067
# March        0.065984
# May          0.121113
# November     0.085167
# October      0.105935
# September    0.072167
# Name: Precip, dtype: float64

# %%
wind_speed_average = monthly_weather.groupby('Month Name')['Wind Speed'].mean()
wind_speed_average
# Out:
# Month Name
# April        18.485000
# August       15.787742
# December     16.082903
# February     17.530973
# January      16.303710
# July         16.307258
# June         16.210667
# March        18.147258
# May          17.326452
# November     16.269333
# October      15.919839
# September    15.162167
# Name: Wind Speed, dtype: float64

# %%
monthly_precip = precip_average.plot(kind="bar", title="Average Precipitation by Month for Cancellations")
monthly_precip.set_xlabel("Month")
monthly_precip.set_ylabel("Avg. Precip (In)")


plt.show()
plt.tight_layout()

# %%
monthly_temp = max_temp_average.plot(kind="bar", title="Average Max Temperature by Month for Cancellations")
monthly_precip.set_xlabel('Month')
monthly_precip.set_ylabel('Avg. Max Temp (F)')

plt.show()
plt.tight_layout()

# %%
monthly_wind_speed = wind_speed_average.plot(kind="bar", title="Average Wind Speed by Month for Cancellations")
monthly_precip.set_xlabel("Month")
monthly_precip.set_ylabel("Wind Speed")

plt.show()
plt.tight_layout()

# %%
# Calculate means
means = monthly_weather['Precip'].mean()
# Calculate standard error on means
sems = monthly_weather['Precip'].sem()

# %%
#Precipitation and months for cancellations
fig, ax = plt.subplots()
ax.errorbar(np.arange(0, len(monthly_weather), 1)+1, means, yerr=sems, fmt="o", color="b")
ax.set_xlim(0, len(means)+1)
ax.set_xlabel("Months")
ax.set_ylabel("Preciptation (Ins)")
plt.legend(loc="best", fontsize="small", fancybox=True)
plt.show()
